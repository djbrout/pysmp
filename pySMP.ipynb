# %%
import IPython.core.display as di

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).load(function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader"></div>

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <a href=""><img src="http://andreaswirth.com/kumpel/wp-content/uploads/2015/08/2031-smp-logo-300x60.png" width="400"></a>

# %%
fakedir=''
resultsdir = ''
isfermigrid = False
cacheddata = True
cd = 'tmp_snse.npz'
import summarizebigrun as sbr
sbr.go(fakedir,resultsdir,cacheddata,cd)
# Out:
# ['Fluxerr', 'HostMag', 'Flux', 'FakeMag', 'FakeZPT', 'FitZPT']
# 92316
# (92316,)
# (92316,)
# saved png
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e0db7094f042> in <module>()
#       5 cd = 'tmp_snse.npz'
#       6 import summarizebigrun as sbr
# ----> 7 sbr.go(fakedir,resultsdir,cacheddata,cd)
#
# /Users/dillonbrout/Dropbox/pysmp/summarizebigrun.py in go(fakedir, resultsdir, cacheddata, cd, isfermigrid)
#      44
#      45     plotpercentageresid(data['Flux'],data['FakeMag'],data['FitZPT'],data['FakeZPT'])
# ---> 46     plotsigmaresid(data['Flux'],data['Fluxerr'],data['FakeMag'], data['FitZPT'], data['FakeZPT'],data['HostMag'])
#      47
#      48
#
# /Users/dillonbrout/Dropbox/pysmp/summarizebigrun.py in plotsigmaresid(flux, fluxerr, fakemag, fitzpt, fakezpt, hostmag)
#     197     ax2.yaxis.set_major_formatter(nullfmt)
#     198     ax3.xaxis.set_major_formatter(nullfmt)
# --> 199
#     200     ax2.hist(d, bins=np.arange(-10, 10, .25), normed=True,label='RMS Fakemag = 99: ' + str(round(rms99, 3))+
#     201                                                                 '\nRMS Fakemag < 99: '+ str(round(rmsr, 3))
#
# /Users/dillonbrout/dillon/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /Users/dillonbrout/dillon/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5983             # this will automatically overwrite bins,
#    5984             # so that each histogram uses the same bins
# -> 5985             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    5986             m = m.astype(float)  # causes problems later if it's an int
#    5987             if mlast is None:
#
# /Users/dillonbrout/dillon/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     503     if not np.all(np.isfinite([mn, mx])):
#     504         raise ValueError(
# --> 505             'range parameter must be finite.')
#     506     if mn == mx:
#     507         mn -= 0.5
#
# ValueError: range parameter must be finite.
